# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import GridSearchCV

import numpy as np
# %matplotlib inline

# %%
# import preprocessed data to dataframes
df = pd.read_pickle('Seattle_data/clean_lisitings.pkl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3816 entries, 0 to 3817
# Data columns (total 87 columns):
# id                                  3816 non-null int64
# listing_url                         3816 non-null object
# scrape_id                           3816 non-null int64
# last_scraped                        3816 non-null object
# name                                3816 non-null object
# summary                             3639 non-null object
# space                               3248 non-null object
# description                         3816 non-null object
# neighborhood_overview               2785 non-null object
# notes                               2211 non-null object
# transit                             2883 non-null object
# thumbnail_url                       3496 non-null object
# medium_url                          3496 non-null object
# picture_url                         3816 non-null object
# xl_picture_url                      3496 non-null object
# host_id                             3816 non-null int64
# host_url                            3816 non-null object
# host_name                           3816 non-null object
# host_since                          3816 non-null datetime64[ns]
# host_location                       3810 non-null object
# host_about                          2959 non-null object
# host_response_time                  3295 non-null object
# host_response_rate                  3816 non-null float64
# host_acceptance_rate                3816 non-null float64
# host_is_superhost                   3816 non-null object
# host_thumbnail_url                  3816 non-null object
# host_picture_url                    3816 non-null object
# host_neighbourhood                  3518 non-null object
# host_listings_count                 3816 non-null float64
# host_total_listings_count           3816 non-null float64
# host_verifications                  3816 non-null object
# host_has_profile_pic                3816 non-null object
# host_identity_verified              3816 non-null object
# street                              3816 non-null object
# neighbourhood                       3400 non-null object
# neighbourhood_cleansed              3816 non-null object
# neighbourhood_group_cleansed        3816 non-null object
# city                                3816 non-null object
# state                               3816 non-null object
# zipcode                             3809 non-null object
# market                              3816 non-null object
# smart_location                      3816 non-null object
# country_code                        3816 non-null object
# country                             3816 non-null object
# latitude                            3816 non-null float64
# longitude                           3816 non-null float64
# is_location_exact                   3816 non-null object
# property_type                       3815 non-null object
# room_type                           3816 non-null object
# accommodates                        3816 non-null int64
# bathrooms                           3800 non-null float64
# bedrooms                            3810 non-null float64
# beds                                3815 non-null float64
# bed_type                            3816 non-null object
# amenities                           3816 non-null object
# price                               3816 non-null float64
# security_deposit                    3816 non-null float64
# cleaning_fee                        3816 non-null float64
# guests_included                     3816 non-null int64
# extra_people                        3816 non-null float64
# minimum_nights                      3816 non-null int64
# maximum_nights                      3816 non-null int64
# calendar_updated                    3816 non-null object
# has_availability                    3816 non-null object
# availability_30                     3816 non-null int64
# availability_60                     3816 non-null int64
# availability_90                     3816 non-null int64
# availability_365                    3816 non-null int64
# calendar_last_scraped               3816 non-null object
# number_of_reviews                   3816 non-null int64
# first_review                        3191 non-null object
# last_review                         3191 non-null object
# review_scores_rating                3816 non-null float64
# review_scores_accuracy              3816 non-null float64
# review_scores_cleanliness           3816 non-null float64
# review_scores_checkin               3816 non-null float64
# review_scores_communication         3816 non-null float64
# review_scores_location              3816 non-null float64
# review_scores_value                 3816 non-null float64
# requires_license                    3816 non-null object
# jurisdiction_names                  3816 non-null object
# instant_bookable                    3816 non-null object
# cancellation_policy                 3816 non-null object
# require_guest_profile_picture       3816 non-null object
# require_guest_phone_verification    3816 non-null object
# calculated_host_listings_count      3816 non-null int64
# reviews_per_month                   3816 non-null float64
# dtypes: datetime64[ns](1), float64(21), int64(13), object(52)
# memory usage: 2.6+ MB

# %%
# The descriptive statistics of the response variable
df['price'].describe()
# Out:
# count    3816.000000
# mean      127.723198
# std        89.139353
# min        20.000000
# 25%        75.000000
# 50%       100.000000
# 75%       150.000000
# max       999.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,10))
dff = df.drop(['id','scrape_id','host_id','latitude','longitude','host_listings_count'],axis=1)
ax = sns.heatmap(dff.corr());
plt.title('Correlation among the numeric features');

# %%
plt.figure(figsize=(12,10))
df['price'].plot();

# %%
def create_features(df):
    '''
    INPUT
    df - preprocessed listings dataframe
    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector
    
    This function cleans df using the following steps to produce X and y:
    1. Drop all the columns that are not relevant for the predicton.
    2. Drop any rows with missing values.
    3. Create X as all the columns that are not the price column
    4. Create y as the price column
    5. Create dummy columns for all the categorical variables, drop the original columns
    '''    
def create_features(df):
    #Drop all columns that are irrelavant for 
    df = df[['room_type','accommodates', 'beds','price','bathrooms','bedrooms','bed_type',
             'security_deposit','cleaning_fee','neighbourhood_group_cleansed','review_scores_cleanliness',
             'extra_people','cancellation_policy','instant_bookable','host_listings_count','review_scores_rating','review_scores_communication']]
    
    # Removing outliers 
    #df = df[np.abs(df.price-df.price.mean())< (3*df.price.std())]
    df = df[df['price'].between(df['price'].quantile(.01), df['price'].quantile(.99))] 

    #Drop any NaNs left in the dataframe
    df = df.dropna(how='any',axis=0)
    # Define the reponse variable
    
    y = df['price']
    
    # Dummy the categorical variables
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for var in  cat_vars:
    # for each cat add dummy var, drop original column    
        df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)
        
    # Define the response column
    X = df.drop(['price'],axis=1)
    
    return X, y 
X,y = create_features(df)

# %%
def lm_mod(X, y,test_size = .30, random_state=42, plot=True):
    
    '''
    INPUT
    X - pandas dataframe, X matrix
    y - pandas dataframe, response variable
    cutoffs - list of ints, cutoff for number of non-zero values in dummy categorical vars
    test_size - float between 0 and 1, default 0.3, determines the proportion of data as test data
    random_state - int, default 42, controls random state for train_test_split
    plot - boolean, default 0.3, True to plot result
    
    OUTPUT
    r2_scores_test - list of floats of r2 scores on the test data
    r2_scores_train - list of floats of r2 scores on the train data
    lm_model - model object from sklearn
    X_train, X_test, y_train, y_test - output from sklearn train test split used for optimal model
    '''
    
    #split the data into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42);
    
    #fit the model and obtain pred response
    lm_model = LinearRegression(normalize=True) 
    lm_model.fit(X_train, y_train)
    y_test_preds = lm_model.predict(X_test)
    y_train_preds = lm_model.predict(X_train)
    
    # r2 and mse values from the train and test sets
    r2_scores_train=r2_score(y_train, y_train_preds)
    print ("r2_scores_train = {}".format(r2_scores_train))
    r2_scores_test=r2_score(y_test, y_test_preds)
    print ("r2_scores_test = {}".format(r2_scores_test))
    
    
    mse_score_train=mean_squared_error(y_train, y_train_preds)
    print ("mse_score_train = {}".format(mse_score_train))
    mse_score_test=mean_squared_error(y_test, y_test_preds)
    print ("mse_score_test = {}".format(mse_score_test))
    
    preds_vs_act = pd.DataFrame(np.hstack([y_test.values.reshape(y_test.size,1), y_test_preds.reshape(y_test.size,1)]));
    preds_vs_act.columns = ['actual', 'preds'];
    preds_vs_act['diff'] = preds_vs_act['actual'] - preds_vs_act['preds'];

    #plt.plot(preds_vs_act['preds'], preds_vs_act['diff'], 'bo');
    plt.plot(preds_vs_act['preds'], preds_vs_act['actual'], 'bo');
    plt.xlabel('predicted');
    plt.ylabel('Actual');
    plt.title('Predictions vs Actual');
    plt.show()
    
    plt.plot(preds_vs_act['preds'], preds_vs_act['diff'], 'ro');
    plt.xlabel('predicted');
    plt.ylabel('diff');
    plt.title('Predictions vs Difference');
    plt.show()
    
    coefs_df = pd.DataFrame()

    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    print(coefs_df.sort_values('abs_coefs', ascending=False))
    
    
    
    return lm_model

# %%
lm_mod(X,y)
# Out:
# r2_scores_train = 0.7630226706077116
# r2_scores_test = -4.092211728910115e+28
# mse_score_train = 1195.4910266899246
# mse_score_test = 2.3956402290203063e+32
#                                                 est_int         coefs  \
# 552   amenities_{Internet,"Wireless Internet","Pets ... -9.324122e+16
# 64    amenities_{"Cable TV","Wireless Internet",Kitc... -8.805012e+16
# 572   amenities_{Internet,"Wireless Internet","Wheel...  8.789603e+16
# 283   amenities_{"Wireless Internet",Kitchen,"Free P... -8.786271e+16
# 75    amenities_{"Cable TV","Wireless Internet",Kitc...  8.251370e+16
# 306   amenities_{"Wireless Internet",Kitchen,"Free P... -8.059999e+16
# 288   amenities_{"Wireless Internet",Kitchen,"Free P... -7.995729e+16
# 555   amenities_{Internet,"Wireless Internet","Pets ...  7.929716e+16
# 276   amenities_{"Wireless Internet",Kitchen,"Elevat...  7.687023e+16
# 312   amenities_{"Wireless Internet",Kitchen,"Free P... -7.494622e+16
# 131   amenities_{"Cable TV",Internet,"Wireless Inter... -7.229541e+16
# 24    amenities_{"Cable TV","Wireless Internet","Air...  7.223648e+16
# 192   amenities_{"Wireless Internet","Air Conditioni... -7.189162e+16
# 139   amenities_{"Cable TV",Internet,"Wireless Inter... -7.129037e+16
# 74    amenities_{"Cable TV","Wireless Internet",Kitc... -7.022196e+16
# 116   amenities_{"Cable TV","Wireless Internet",Pool...  6.867562e+16
# 499   amenities_{Internet,"Wireless Internet","Air C... -6.860452e+16
# 267   amenities_{"Wireless Internet",Heating,Washer,... -6.683569e+16
# 53    amenities_{"Cable TV","Wireless Internet",Kitc...  6.489070e+16
# 132   amenities_{"Cable TV",Internet,"Wireless Inter... -6.346431e+16
# 446   amenities_{"Wireless Internet",Kitchen,Heating... -6.041240e+16
# 282   amenities_{"Wireless Internet",Kitchen,"Free P...  5.851900e+16
# 28    amenities_{"Cable TV","Wireless Internet","Air... -5.724185e+16
# 491   amenities_{Internet,"Wireless Internet","Air C... -5.571261e+16
# 169   amenities_{"Elevator in Building","Buzzer/Wire... -5.475333e+16
# 316   amenities_{"Wireless Internet",Kitchen,"Free P...  5.407570e+16
# 177   amenities_{"Wireless Internet","Air Conditioni...  5.345590e+16
# 133   amenities_{"Cable TV",Internet,"Wireless Inter... -5.220503e+16
# 114   amenities_{"Cable TV","Wireless Internet",Kitc... -5.128695e+16
# 108   amenities_{"Cable TV","Wireless Internet",Kitc... -4.941634e+16
# ...                                                 ...           ...
# 2612  amenities_{TV,Internet,"Wireless Internet","Wh...  0.000000e+00
# 2623  amenities_{TV,Internet,"Wireless Internet","Wh...  0.000000e+00
# 3094  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2844  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3032  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2920  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3039  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2862  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3044  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3045  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3047  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3049  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2860  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3054  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3055  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2856  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3061  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3066  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2852  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3070  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2851  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3073  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2850  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2849  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3077  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3078  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2848  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 3083  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2846  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
# 2776  amenities_{TV,Internet,"Wireless Internet",Kit...  0.000000e+00
#
#          abs_coefs
# 552   9.324122e+16
# 64    8.805012e+16
# 572   8.789603e+16
# 283   8.786271e+16
# 75    8.251370e+16
# 306   8.059999e+16
# 288   7.995729e+16
# 555   7.929716e+16
# 276   7.687023e+16
# 312   7.494622e+16
# 131   7.229541e+16
# 24    7.223648e+16
# 192   7.189162e+16
# 139   7.129037e+16
# 74    7.022196e+16
# 116   6.867562e+16
# 499   6.860452e+16
# 267   6.683569e+16
# 53    6.489070e+16
# 132   6.346431e+16
# 446   6.041240e+16
# 282   5.851900e+16
# 28    5.724185e+16
# 491   5.571261e+16
# 169   5.475333e+16
# 316   5.407570e+16
# 177   5.345590e+16
# 133   5.220503e+16
# 114   5.128695e+16
# 108   4.941634e+16
# ...            ...
# 2612  0.000000e+00
# 2623  0.000000e+00
# 3094  0.000000e+00
# 2844  0.000000e+00
# 3032  0.000000e+00
# 2920  0.000000e+00
# 3039  0.000000e+00
# 2862  0.000000e+00
# 3044  0.000000e+00
# 3045  0.000000e+00
# 3047  0.000000e+00
# 3049  0.000000e+00
# 2860  0.000000e+00
# 3054  0.000000e+00
# 3055  0.000000e+00
# 2856  0.000000e+00
# 3061  0.000000e+00
# 3066  0.000000e+00
# 2852  0.000000e+00
# 3070  0.000000e+00
# 2851  0.000000e+00
# 3073  0.000000e+00
# 2850  0.000000e+00
# 2849  0.000000e+00
# 3077  0.000000e+00
# 3078  0.000000e+00
# 2848  0.000000e+00
# 3083  0.000000e+00
# 2846  0.000000e+00
# 2776  0.000000e+00
#
# [3249 rows x 3 columns]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
