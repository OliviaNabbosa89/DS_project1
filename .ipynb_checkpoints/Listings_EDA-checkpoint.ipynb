# %% [markdown]
# # Exploratory Data Analysis
#   In this part of the project, I use the preprocessed Settle data to perform EDA answer the following questions;
#     * What is the most popular neigbourhood in Seattle?
#     * What are the average prices in the different neighbourhoods?
#     * What are the average prices in the different property types?
#     * What are the average prices in the different room types?
#     * What are the average cleaning fees of the different room types?
#     * What are the average cleaning fees of the different property types?
#     * What are the commonest amnenities?
#     *

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl
import folium
from folium.plugins import HeatMap
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Import data

# %%
# import preprocessed data to dataframes
df = pd.read_pickle('Seattle_data/clean_lisitings.pkl')

# %% [markdown]
# # Statistical summary

# %%
# Statistical summary about the relevant numeric columns
# I use the built in describe function to get the statistical summary of the relevant numeric columns.
# I exclude the irrelevant columns ['id','scrape_id','host_id','latitude','longitude']
df.drop(['id','scrape_id','host_id','latitude','longitude'],axis=1).describe().T
# Out:
#                                  count        mean          std    min  \
# host_response_rate              3816.0   95.584906    11.165601  17.00
# host_acceptance_rate            3816.0   99.973795     1.618810   0.00
# host_listings_count             3816.0    7.157757    28.628149   1.00
# host_total_listings_count       3816.0    7.157757    28.628149   1.00
# accommodates                    3816.0    3.350105     1.977876   1.00
# bathrooms                       3800.0    1.259605     0.590494   0.00
# bedrooms                        3810.0    1.308136     0.883359   0.00
# beds                            3815.0    1.735780     1.139654   1.00
# price                           3816.0  127.723198    89.139353  20.00
# security_deposit                3816.0  254.484832   103.203514  95.00
# cleaning_fee                    3816.0   61.724076    41.731780   5.00
# guests_included                 3816.0    1.672956     1.311293   0.00
# extra_people                    3816.0   10.666667    17.588153   0.00
# minimum_nights                  3816.0    2.369759    16.310159   1.00
# maximum_nights                  3816.0  780.558438  1683.975176   1.00
# availability_30                 3816.0   16.786426    12.172902   0.00
# availability_60                 3816.0   36.817610    23.334218   0.00
# availability_90                 3816.0   58.088836    34.057422   0.00
# availability_365                3816.0  244.876834   126.720185   0.00
# number_of_reviews               3816.0   22.235063    37.737349   0.00
# review_scores_rating            3816.0   94.539262     6.021801  20.00
# review_scores_accuracy          3816.0    9.698899     0.649838   2.00
# review_scores_cleanliness       3816.0    9.556398     0.726070   3.00
# review_scores_checkin           3816.0    9.823375     0.547831   2.00
# review_scores_communication     3816.0    9.841981     0.522549   2.00
# review_scores_location          3816.0    9.675839     0.591334   4.00
# review_scores_value             3816.0    9.546122     0.713451   2.00
# calculated_host_listings_count  3816.0    2.947327     5.894405   1.00
# reviews_per_month               3816.0    2.078919     1.666400   0.02
#
#                                    25%          50%          75%        max
# host_response_rate              100.00   100.000000   100.000000     100.00
# host_acceptance_rate            100.00   100.000000   100.000000     100.00
# host_listings_count               1.00     1.000000     3.000000     502.00
# host_total_listings_count         1.00     1.000000     3.000000     502.00
# accommodates                      2.00     3.000000     4.000000      16.00
# bathrooms                         1.00     1.000000     1.000000       8.00
# bedrooms                          1.00     1.000000     2.000000       7.00
# beds                              1.00     1.000000     2.000000      15.00
# price                            75.00   100.000000   150.000000     999.00
# security_deposit                250.00   254.484832   254.484832     995.00
# cleaning_fee                     35.00    61.724076    65.000000     300.00
# guests_included                   1.00     1.000000     2.000000      15.00
# extra_people                      0.00     0.000000    20.000000     300.00
# minimum_nights                    1.00     2.000000     2.000000    1000.00
# maximum_nights                   60.00  1125.000000  1125.000000  100000.00
# availability_30                   2.00    20.000000    30.000000      30.00
# availability_60                  13.00    46.000000    59.000000      60.00
# availability_90                  28.00    73.000000    89.000000      90.00
# availability_365                124.75   308.000000   360.000000     365.00
# number_of_reviews                 2.00     9.000000    26.000000     474.00
# review_scores_rating             94.00    95.000000    98.000000     100.00
# review_scores_accuracy           10.00    10.000000    10.000000      10.00
# review_scores_cleanliness         9.00    10.000000    10.000000      10.00
# review_scores_checkin            10.00    10.000000    10.000000      10.00
# review_scores_communication      10.00    10.000000    10.000000      10.00
# review_scores_location            9.00    10.000000    10.000000      10.00
# review_scores_value               9.00    10.000000    10.000000      10.00
# calculated_host_listings_count    1.00     1.000000     2.000000      37.00
# reviews_per_month                 0.83     2.000000     2.660000      12.15

# %% [markdown]
# # Correlation among the numeric features

# %%
# Get the correlation of the different numeric columns
# I use the corr built in function and the seaborn heatmap.

# Findings
# Based on the heatmap, there are 3 clusters of correclations in the Seattle listings data.

# 1. We see a fairly strong correlation amon the scores and reviews (lower_right corner of the heatmap)
# 2. There is a strong correlation among the availability measures which is expected since they are cummulative(centre)
# 3. There is a fairly strong correlation among the fees, prices and room specifics (upper left corner)

# In the rest of this note book we will deep dive into these correlations while answering the questions listed above

plt.figure(figsize=(12,10))
dff = df.drop(['id','scrape_id','host_id','latitude','longitude','host_listings_count'],axis=1)
ax = sns.heatmap(dff.corr());
plt.title('Correlation among the numeric features');

# %% [markdown]
# # Descriptive Statistics

# %%
'''
Input:

output:
'''

def stats_description(df, col1, col2):
    dict1 = df.groupby(col1)[col2].mean().to_dict()
    dict2 = df.groupby(col1)[col2].median().to_dict()
    dict3 = df.groupby(col1)[col2].std().to_dict()
    dict4 = df.groupby(col1)[col2].max().to_dict()
    dict5 = df.groupby(col1)[col2].min().to_dict()
    dict6 = df[col1].value_counts().to_dict()
    dicts = [dict1, dict2, dict3, dict4, dict5,dict6]
    result_dict = {}
    for d in dicts:
        for k, v in d.items():
            try:
                result_dict.setdefault(k, []).extend(v)
            except TypeError:
                result_dict[k].append(v)
    
    xxx = pd.DataFrame(result_dict, index = ['mean_' + col2, 'median_' + col2, 'std_' + col2, 'max_' + col2, 'min_' + col2, 'Counts']).T
    xxx['Perc'] = xxx['Counts']/np.sum(xxx['Counts'])
    
    plt.figure(figsize=(12,10))
    ax=sns.countplot(x= col1,data=df,palette='Spectral')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
    plt.title('The Listings count in Seattle per '+col1);
    
    plt.figure(figsize=(12, 10))
    ax = sns.barplot(data = df, x = col1, y = col2,estimator = np.mean,palette='Set3')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    #ax.set_ylim(0, 450);
    plt.title('The ' + col2 + ' for the different ' + col1+ ' in Seattle');
    
    plt.figure(figsize=(12, 10))
    ax = sns.boxplot(data = df, x = col1, y = col2, fliersize = 0.1,palette='Set1')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    #ax.set_ylim(0, 450);
    plt.title('The ' + col2 + ' in the different neigbourhoods in Seattle');
    
    return xxx

# %% [markdown]
# # Neighbourhood - Prices

# %%
stats_description(df,"neighbourhood_group_cleansed",'price')
# Out:
#                      mean_price  median_price   std_price  max_price  \
# Ballard              124.682609          95.0   87.925033      475.0
# Beacon Hill           94.669492          75.0   61.528682      399.0
# Capitol Hill         130.592593         105.0   92.442331      750.0
# Cascade              140.101124         115.0  112.179042      775.0
# Central Area         128.338753         100.0   80.260558      500.0
# Delridge              83.278481          72.0   41.797110      300.0
# Downtown             154.329545         139.0   90.947831      999.0
# Interbay             109.727273          90.0   60.003485      250.0
# Lake City             92.671642          70.0   57.212625      252.0
# Magnolia             177.672131         129.0  150.078726      950.0
# Northgate             88.550000          79.5   38.642110      200.0
# Other neighborhoods  118.869928          99.0   80.736776      680.0
# Queen Anne           157.223729         119.0  115.863385      975.0
# Rainier Valley        91.899371          80.0   52.505599      300.0
# Seward Park          108.477273          93.0   71.718276      375.0
# University District   93.639344          85.0   59.721816      350.0
# West Seattle         141.359606         109.0   89.147801      495.0
#
#                      min_price  Counts      Perc
# Ballard                   25.0   230.0  0.060273
# Beacon Hill               30.0   118.0  0.030922
# Capitol Hill              22.0   567.0  0.148585
# Cascade                   42.0    89.0  0.023323
# Central Area              35.0   369.0  0.096698
# Delridge                  35.0    79.0  0.020702
# Downtown                  35.0   528.0  0.138365
# Interbay                  50.0    11.0  0.002883
# Lake City                 35.0    67.0  0.017558
# Magnolia                  30.0    61.0  0.015985
# Northgate                 30.0    80.0  0.020964
# Other neighborhoods       25.0   794.0  0.208071
# Queen Anne                20.0   295.0  0.077306
# Rainier Valley            25.0   159.0  0.041667
# Seward Park               34.0    44.0  0.011530
# University District       28.0   122.0  0.031971
# West Seattle              30.0   203.0  0.053197

# %% [markdown]
# # Property_type - prices

# %%
stats_description(df,"property_type",'price')
# Out:
#                  mean_price  median_price   std_price  max_price  min_price  \
# Apartment        122.872216         110.0   66.583144      999.0       20.0
# Bed & Breakfast  112.054054          99.0   55.840022      299.0       30.0
# Boat             282.375000         150.0  281.327434      775.0       75.0
# Bungalow         115.615385          95.0   75.226922      349.0       65.0
# Cabin            104.666667          95.0   55.218053      300.0       52.0
# Camper/RV        120.461538          82.0   95.375237      375.0       45.0
# Chalet            98.500000          98.5   51.618795      135.0       62.0
# Condominium      151.109890         115.0  111.091099      700.0       50.0
# Dorm              39.500000          39.5    2.121320       41.0       38.0
# House            131.848080          95.0  104.823698      975.0       25.0
# Loft             135.700000         102.5   79.825836      425.0       25.0
# Other             94.681818          86.5   40.449129      170.0       39.0
# Tent              54.000000          65.0   17.464249       65.0       25.0
# Townhouse        129.457627          97.0   92.397103      498.0       28.0
# Treehouse        101.000000          55.0   85.807925      200.0       48.0
# Yurt             100.000000         100.0         NaN      100.0      100.0
#
#                  Counts      Perc
# Apartment        1706.0  0.447182
# Bed & Breakfast    37.0  0.009699
# Boat                8.0  0.002097
# Bungalow           13.0  0.003408
# Cabin              21.0  0.005505
# Camper/RV          13.0  0.003408
# Chalet              2.0  0.000524
# Condominium        91.0  0.023853
# Dorm                2.0  0.000524
# House            1733.0  0.454260
# Loft               40.0  0.010485
# Other              22.0  0.005767
# Tent                5.0  0.001311
# Townhouse         118.0  0.030931
# Treehouse           3.0  0.000786
# Yurt                1.0  0.000262

# %% [markdown]
# # Property_type - Cleaning_fee

# %%
stats_description(df,"property_type",'cleaning_fee')
# Out:
#                  mean_cleaning_fee  median_cleaning_fee  std_cleaning_fee  \
# Apartment                59.156470            61.724076         33.127956
# Bed & Breakfast          47.553555            61.724076         18.183196
# Boat                     86.896529            61.724076         82.177101
# Bungalow                 55.167094            50.000000         47.486206
# Cabin                    43.596033            50.000000         21.361015
# Camper/RV                39.893875            30.000000         19.705183
# Chalet                   30.000000            30.000000          7.071068
# Condominium              65.579752            61.724076         40.324836
# Dorm                     33.862038            33.862038         39.402872
# House                    65.184574            61.724076         49.360824
# Loft                     56.635325            61.724076         26.258479
# Other                    43.573654            50.000000         30.807169
# Tent                     61.724076            61.724076          0.000000
# Townhouse                60.457612            61.724076         39.758404
# Treehouse                61.724076            61.724076          0.000000
# Yurt                     25.000000            25.000000               NaN
#
#                  max_cleaning_fee  min_cleaning_fee  Counts      Perc
# Apartment              274.000000          5.000000  1706.0  0.447182
# Bed & Breakfast         61.724076         10.000000    37.0  0.009699
# Boat                   275.000000         15.000000     8.0  0.002097
# Bungalow               200.000000         12.000000    13.0  0.003408
# Cabin                   61.724076          5.000000    21.0  0.005505
# Camper/RV               61.724076         15.000000    13.0  0.003408
# Chalet                  35.000000         25.000000     2.0  0.000524
# Condominium            250.000000          5.000000    91.0  0.023853
# Dorm                    61.724076          6.000000     2.0  0.000524
# House                  300.000000          5.000000  1733.0  0.454260
# Loft                   150.000000          7.000000    40.0  0.010485
# Other                  125.000000         10.000000    22.0  0.005767
# Tent                    61.724076         61.724076     5.0  0.001311
# Townhouse              210.000000          7.000000   118.0  0.030931
# Treehouse               61.724076         61.724076     3.0  0.000786
# Yurt                    25.000000         25.000000     1.0  0.000262

# %% [markdown]
# # Room_type - Prices

# %%
df['room_type'].value_counts()
room_dict = df['room_type'].value_counts().to_dict()
room_list=[]
for key, value in room_dict.items():
    temp = [key,value]
    room_list.append(temp)

# make dataframe from neighborhood_list
dff = pd.DataFrame(room_list, columns=['Room','Count'])
dff['Perc'] = dff['Count']/np.sum(dff['Count'])

labels = 'Entire home/apt', 'Private room', 'Shared room'
sizes = [dff['Perc'][0], dff['Perc'][1], dff['Perc'][2]]
colors = ['gold', 'yellowgreen','lightskyblue']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.figure(figsize=(12,10))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

stats_description(df,"room_type",'price')
# Out:
#                  mean_price  median_price  std_price  max_price  min_price  \
# Entire home/apt  155.485121         126.0  95.100584      999.0       39.0
# Private room      75.044828          69.0  34.603905      399.0       20.0
# Shared room       47.547009          40.0  19.372704      118.0       22.0
#
#                  Counts      Perc
# Entire home/apt  2539.0  0.665356
# Private room     1160.0  0.303983
# Shared room       117.0  0.030660

# %% [markdown]
# # Room_type - Cleaning fee

# %%
stats_description(df,"room_type",'cleaning_fee')
# Out:
#                  mean_cleaning_fee  median_cleaning_fee  std_cleaning_fee  \
# Entire home/apt          71.734013            61.724076         45.549743
# Private room             41.598398            50.000000         22.191055
# Shared room              44.036516            60.000000         20.041334
#
#                  max_cleaning_fee  min_cleaning_fee  Counts      Perc
# Entire home/apt             300.0               5.0  2539.0  0.665356
# Private room                150.0               5.0  1160.0  0.303983
# Shared room                  75.0               5.0   117.0  0.030660

# %% [markdown]
# # Amenities

# %%
#The top amnenities in included in the Seattle property.
from collections import Counter
results = Counter()
df['amenities'].str.strip('{}')\
               .str.replace('"', '')\
               .str.lstrip('\"')\
               .str.rstrip('\"')\
               .str.split(',')\
               .apply(results.update)

sub_df = pd.DataFrame(results.most_common(25), columns=['amenity', 'count'])
sub_df.sort_values(by=['count'], ascending=True).plot(kind='barh', x='amenity', y='count',  
                                                      figsize=(12,10), legend=False,
                                                      title='Amenities',cmap='Set2')
plt.xlabel('Count');

# %% [markdown]
# # Host Verfication methods

# %%
#The top host verification methods in Seattle
from collections import Counter
results = Counter()
df['host_verifications'].str.strip('[]')\
               .str.split(',')\
               .apply(results.update)

plt.figure(figsize=(15,10))
ax = pd.DataFrame(results.most_common(10), columns=['host_verifications', 'count'])
ax.sort_values(by=['count'], ascending=True).plot(kind='barh', x='host_verifications', y='count',  
                                                      figsize=(12,10), legend=False,
                                                      title='Methods of Verification',cmap='Set1')
plt.xlabel('Count');

# %%
plt.figure(figsize=(12,10))
sns.barplot(x='cancellation_policy',y='security_deposit',data=df,palette = "hot");

# %%
coordinates = df[['latitude','longitude']].values
res = df[df.review_scores_cleanliness <= 6]
m = folium.Map([47.620422, -122.349358], zoom_start=12)
m.add_child(HeatMap(coordinates, radius=12))
for i,row in res.iterrows():
    popup_text = f"""
        <b>{row['room_type']}</b></br>
        <hr style='width:200px; margin-top:0px; margin-bottom:10px;'>
        <b>{row['review_scores_cleanliness']}</b></br>
        <hr style='width:200px; margin-top:0px; margin-bottom:10px;'>
        {str(row['neighbourhood_group_cleansed'].encode('raw_unicode_escape'))[2:-1]}
    """
    folium.Marker([row['latitude'], row['longitude']], popup=popup_text).add_to(m)
    if row['room_type'] == 'Entire home/apt':
        marker= folium.Marker([row['latitude'], row['longitude']], popup=popup_text,icon=folium.Icon(color ='green',icon_color='green'))
        marker.add_to(m)       
        
    elif row['room_type'] == 'Private room':
        marker= folium.Marker([row['latitude'], row['longitude']], popup=popup_text,icon=folium.Icon(color ='red',icon_color='red'))
        marker.add_to(m)
    else:
        marker= folium.Marker([row['latitude'], row['longitude']], popup=popup_text,icon=folium.Icon(color ='purple',icon_color='red'))
        marker.add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c687b82766be471d8c7390f3dad54d6a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c687b82766be471d8c7390f3dad54d6a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c687b82766be471d8c7390f3dad54d6a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c687b82766be471d8c7390f3dad54d6a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
m.save('Seattle_data/Seattle_listings_heatmap.html')
